# %%
import pandas as pd

# %%
data = pd.read_excel("./others/database.xlsx")

# %%
data
# Out:
#    ROLL_NO               STUDENT_NAME   MONTH   PHY  PHY_MM  CHEM  CHEM_MM  \
# 0    T9-01                 Rooh Allah  202207  18.0      30  10.5       30
# 1    T9-02          S. Ali Naqi Jafri  202207  24.0      30  15.0       30
# 2    T9-03      S. Haider Abbas Zaidi  202207  21.0      30   9.5       30
# 3    T9-04      S. Hassan Abbas Rizvi  202207  17.0      30  16.0       30
# 4    T9-05      S. M. Ali Osaja Rizvi  202207   0.0      30  13.5       30
# ..     ...                        ...     ...   ...     ...   ...      ...
# 95   T9-16               Saim Hussain  202211  30.5      50  35.0       50
# 96   T9-18               S. Ayaan Ali  202211  42.0      50  42.0       50
# 97   T9-20  S. Dur e Aden Hasan Rizvi  202211  40.5      50  38.5       50
# 98   T9-21      S. Ghazi Abbas Askari  202211  39.0      50  38.0       50
# 99   T9-22                    Sajjad   202211  40.0      50   0.0       50
#
# ...

# %%
roll_nos = data["ROLL_NO"].unique()

# %%
from database_func import insert_student_data

# %%
for roll_no in roll_nos:
#     print(roll_no,data[data["ROLL_NO"]==roll_no]["STUDENT_NAME"].iloc[0])
    insert_student_data(roll_no,data[data["ROLL_NO"]==roll_no]["STUDENT_NAME"].iloc[0])
